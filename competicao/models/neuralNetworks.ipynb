# %% [markdown]
# # Neural Networks

# %%
import sklearn as skl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler

train = pd.read_csv('../data/train_radiomics_hipocamp_cleaned.csv')
test = pd.read_csv('../data/test_radiomics_hipocamp_cleaned.csv')

# %%
X_train = train.drop('Transition', axis=1)
y_train = train['Transition']

X_teste = test

# %%
scaler = StandardScaler()

X_train_normalized = scaler.fit_transform(X_train)
X_teste_normalized = scaler.fit_transform(X_teste)

# %%
clf = MLPClassifier(random_state=183, max_iter=2000)

params = {
    'activation': ['relu', 'tanh', 'logistic'],
    'learning_rate_init': [0.05, 0.1, 0.3],  # Learning rate
    'hidden_layer_sizes': [(50,50), (100,100)],
}

grid = GridSearchCV(estimator=clf,
                    param_grid=params,
                    cv=10,
                    n_jobs=5,
                    verbose=2)
grid.fit(X_train_normalized, y_train)
grid.best_score_, grid.best_params_
# Out:
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   0.9s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.0s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.4s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.6s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.6s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   0.7s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   0.9s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.0s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.3s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   0.6s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   0.8s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   0.6s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.9s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   0.6s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.6s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.7s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   0.8s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   1.5s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   1.3s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   1.6s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   2.4s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   1.7s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   1.1s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   2.2s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   2.3s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.4s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   2.0s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   2.4s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.3s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.4s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.5s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   0.9s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.7s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   2.2s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   1.2s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.8s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.9s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.8s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.9s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   1.0s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.7s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.9s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.9s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   1.0s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.8s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.8s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.6s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   0.9s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.1s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.5s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.3s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.2s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.3s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   1.0s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   2.4s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   2.5s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   1.1s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   3.8s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   2.7s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   2.1s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   2.9s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   2.3s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   2.6s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   1.8s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.5s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.5s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   2.4s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.5s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   2.2s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.3s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   1.3s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.8s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.8s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.8s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.6s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   1.6s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   2.3s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   2.8s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   2.3s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   2.8s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   3.0s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   2.1s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   1.7s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   2.4s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   3.0s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.5s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.7s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.7s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.8s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.7s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.7s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.6s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   2.1s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.2s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   1.8s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.4s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   2.7s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   3.0s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   3.1s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   3.5s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   1.4s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   2.8s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   1.3s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   3.2s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   2.2s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   3.2s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.05; total time=   3.7s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   1.6s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   1.1s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   2.4s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   2.2s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   1.1s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   2.4s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   1.1s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   1.5s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   3.0s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   1.4s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.1; total time=   2.6s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   1.0s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   1.3s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   1.2s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   1.1s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50), learning_rate_init=0.3; total time=   1.4s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   4.3s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   5.1s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   6.1s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   5.6s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   7.7s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   4.6s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   5.5s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   6.1s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   3.3s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.05; total time=   8.1s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   2.3s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   2.9s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   3.6s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   3.4s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   2.1s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   2.6s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   2.4s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   4.2s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.6s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   1.2s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   3.5s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.1; total time=   2.7s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   1.5s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   2.3s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   1.7s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   1.7s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   1.6s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   1.4s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100), learning_rate_init=0.3; total time=   1.5s
# (0.4198924731182796,
#  {'activation': 'tanh',
#   'hidden_layer_sizes': (50, 50),
#   'learning_rate_init': 0.1})

# %%
mapping = {0: 'CN-CN', 1: 'CN-MCI', 2: 'MCI-MCI', 3: 'MCI-AD', 4: 'AD-AD'}

predictions = grid.predict(X_teste)

predictions_mapped = [mapping[pred] for pred in predictions]

predict_data = {'Result': predictions_mapped}
df = pd.DataFrame(predict_data)
df.index += 1
df.index.name = 'RowId'

df.to_csv(f'../output/nnPrediction.csv')
# Out:
# /Users/lapata/miniconda3/envs/myenv/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but MLPClassifier was fitted without feature names
#   warnings.warn(
